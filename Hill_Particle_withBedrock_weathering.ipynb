# %%
"""
Geol701j 
John Volk
Lab 6, Hillslope Evolution
Python 2 
"""
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## x spatial grid for simulation and plotting
x_grid = np.linspace(-100,100,201) # unit meter grid

# %% [markdown]
# ###Discrete or particle based approach###
#
# 1. Production of soil (from bedrock)
# 2. Transport of soil

# %%
def getRandLocation(x_grid=x_grid):
    """returns a random index of the x_grid and return it"""
    return np.random.choice(len(x_grid))

# %%
def getRandDir():
    return np.random.choice(['L','R'])

# %% [markdown]
# ###Soil production from bedrock weathering as exponential decay with soil depth###
#
# $$
# \begin{align}
# \frac{de}{dt} &= P_0 e^{-kh} \\
# \end{align}
# $$
#
# Where $\frac{de}{dt}$ is the weathering rate, $P_0$ is the potential weathering rate, $k$ is an emprical constant, and $h$ is the soil thickness.

# %%
def weather(bedrock_profile, elev_profile):
    """ Weathers bedrock - produces soil,
    should be applied once per year"""
    soil_profile = elev_profile - bedrock_profile
    soil_profile[soil_profile <=0] = 0
    P = .5
    k = 4
    
    weathered = P * np.exp(-k * soil_profile)
    elev_profile += weathered
    bedrock_profile -= weathered
    bedrock_profile[bedrock_profile <= 0] = 0
    
    return bedrock_profile, elev_profile

# %%
def weatherHumped(bedrock_profile, elev_profile):
    soil_profile = elev_profile - bedrock_profile
    soil_profile[soil_profile <=0] = 0
    P = 0.5
    h = 0.7
    
    weathered = P * (soil_profile/h) * np.exp(-soil_profile/h)
    elev_profile += weathered
    bedrock_profile -= weathered
    #bedrock_profile[bedrock_profile <= 0] = 0
    
    return bedrock_profile, elev_profile

# %% [markdown]
# ###Probabilities for particles to continue moving:###
#    * 1 if drop
#    * 7/8 if flat
#    * 1/8 if up by one particle
#    * 0 if up by two or more particles

# %%
def moveDepositSed(elev_profile, bedrock_profile, psize, x_grid=x_grid):
    sedloc = sedinitloc = getRandLocation()
    seddir = getRandDir()
    
    ## a check if bedrock if so, then no particlea to move
    if elev_profile[sedloc] <= bedrock_profile[sedloc]:
        return elev_profile
    
    moving = True         
    if seddir == 'R':
        while moving:
            if sedloc == len(x_grid)-1:
                elev_profile[sedinitloc] -= psize 
                moving = False
                break
            if elev_profile[sedloc] - elev_profile[sedloc+1] > 0:
                sedloc += 1
                continue
            elif elev_profile[sedloc] - elev_profile[sedloc+1] <= -2*psize:
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                break
            elif (elev_profile[sedloc] == elev_profile[sedloc+1]) and (np.random.rand() >= 7/8.):
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                break  
            elif (elev_profile[sedloc] - elev_profile[sedloc+1] >= -psize) and (np.random.rand() >= 1/8.):
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                break      
            else:
                sedloc += 1   
        return elev_profile
                
    elif seddir == 'L':
        while moving:            
            if sedloc == 0:
                elev_profile[sedinitloc] -= psize 
                moving = False
                break
            if elev_profile[sedloc] - elev_profile[sedloc-1] > 0:
                sedloc -= 1
                continue
            elif elev_profile[sedloc] - elev_profile[sedloc-1] <= -2*psize:
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                continue
            elif (elev_profile[sedloc] == elev_profile[sedloc-1]) and (np.random.rand() >= 7/8.):
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                break   
            elif (elev_profile[sedloc] - elev_profile[sedloc-1] >= -psize) and (np.random.rand() >= 1/8.):
                elev_profile[sedloc] += psize
                elev_profile[sedinitloc] -= psize  
                moving = False
                break     
            else:
                sedloc -= 1 
        return elev_profile

# %%
#######
## Parameters and boundary conditions
#######

## initial height from first uplift 
init_height = .15 
particle_size = .31*2.75 # .3*2.75
uplift_height = .06 ## .06
## initial elevation profile
## boundary conditions are constant height of zero
elev = np.zeros_like(x_grid) + (init_height)
bedrock = np.zeros_like(x_grid) + (init_height*0.7)
elev[0] = 0  
elev[len(x_grid)-1] = 0 

fig = plt.figure(figsize=(12,8))

for i in range(1000000):
    elev = moveDepositSed(elev, bedrock, particle_size)
    if i % 50 == 0: #50
        bedrock, elev = weather(bedrock, elev)
    if i % 400 == 0: #400
        elev = elev + np.zeros_like(len(x_grid)) + (uplift_height)*np.random.rand()
        bedrock = bedrock + np.zeros_like(len(x_grid)) + (uplift_height)*np.random.rand()
        elev[0] = 0  
        elev[len(x_grid)-1] = 0 
    if i % 10000 == 0:
        #plt.plot(x_grid, elev, color='brown', alpha=.3)      
        plt.fill_between(x_grid, elev, bedrock, color='moccasin', alpha=.9)      
        plt.plot(x_grid, bedrock, 'darkslategray', alpha = 0.3)
        #plt.fill_between(x_grid, bedrock,np.zeros_like(x_grid), color='darkslategray', alpha = 0.2)
        plt.xlim(-100,100)
        plt.ylim(0,np.max(elev)+10)       
        #plt.fill(x_grid, elev, 'moccasin', alpha=.9)
        #plt.plot(x_grid, bedrock, 'darkslategray', alpha = 0.5)
        #plt.fill(x_grid, bedrock, 'darkslategray', alpha = 0.5)
        display(plt.gcf()) 
        clear_output(wait=True)        
        
plt.plot(x_grid, bedrock, 'k', alpha = 0.7, label='Bedrock')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-437c86f1a74f> in <module>()
#      35         #plt.plot(x_grid, bedrock, 'darkslategray', alpha = 0.5)
#      36         #plt.fill(x_grid, bedrock, 'darkslategray', alpha = 0.5)
# ---> 37         display(plt.gcf())
#      38         clear_output(wait=True)
#      39
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in display(*objs, **kwargs)
#     129             publish_display_data('display', obj, metadata)
#     130         else:
# --> 131             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     132             if metadata:
#     133                 # kwarg-specified metadata gets precedence
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in format(self, obj, include, exclude)
#     198             md = None
#     199             try:
# --> 200                 data = formatter(obj)
#     201             except:
#     202                 # FIXME: log the exception
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in warn_format_error(method, self, *args, **kwargs)
#     231     """decorator for warning on failed format call"""
#     232     try:
# --> 233         r = method(self, *args, **kwargs)
#     234     except NotImplementedError as e:
#     235         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     348                 pass
#     349             else:
# --> 350                 return printer(obj)
#     351             # Finally look for special method names
#     352             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     218
#     219     if 'png' in formats:
# --> 220         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     221     if 'retina' in formats or 'png2x' in formats:
#     222         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     128
#     129     bytes_io = BytesIO()
# --> 130     fig.canvas.print_figure(bytes_io, **kw)
#     131     data = bytes_io.getvalue()
#     132     if fmt == 'svg':
#
# /usr/lib/pymodules/python2.7/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2094                 orientation=orientation,
#    2095                 bbox_inches_restore=_bbox_inches_restore,
# -> 2096                 **kwargs)
#    2097         finally:
#    2098             if bbox_inches and restore_bbox:
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     502             _png.write_png(renderer._renderer.buffer_rgba(),
#     503                            renderer.width, renderer.height,
# --> 504                            filename_or_obj, self.figure.dpi)
#     505         finally:
#     506             if close:
#
# KeyboardInterrupt:
